# %% [markdown]
# ## Cellular Automata Traffic- MOTORWAY MADNESS II - Logbook 4  ##
#
# ### Analysis ###

# %%
#imports
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 8/3 ###
#
# I produced a function that integrated both the single lane and the triple lane systems together, so that would be the only one that needed to be called. Within the function one would specify how many lanes the system should have, how the function was visualised, if there was a lane closure (and when it occured), as well as the usual parameters that had been passed into the functions before.
#
# This was saved in traffic.py and can be imported like so:

# %%
from traffic import all

# %% [markdown]
# ### 8/3 cont ###
#
# Then I added an alternative visulaisation system, whereby a vehicles velocity would would be indicated by the colour that it is represented by, this would prove more useful in cases such as the lane closure scenario
#
# We defined a few values to collect for the single lane system, and thus will include an array to store data for the 3 lane system too, so that we can call the function and plot figure to compare the effects of differing paramaters.

# %% [markdown]
# Looking at density variations:

# %%
fig12 = plt.figure(figsize=(20,7))
ax12 = fig12.add_subplot(111)
index = 0
max_iters=100
timesteps = int(100)
road_len = int(100)
vmax = 5
dawdeling = 0.1
labels=[]
for i in range(8, 27, 3):
    average=np.zeros(timesteps)
    iters = 0
    while iters in range(max_iters):
        functioncall =Traffic(road_len, 0, vmax, 0, i/100, 0.0, 0.0, dawdeling, 0.8, 1, 1, timesteps, 1, 1, 1)[:,3]
        average += functioncall
        iters+=1
    average /= max_iters
    index+=1
    if index == 1:
        colour = "r"
    elif index == 2:
        colour = "b"

    elif index == 3:
        colour = "g"

    elif index == 4:
        colour = "c"

    elif index == 5:
        colour = "m"
        
    elif index == 6:
        colour = "y"
        
    elif index == 7:
        colour = 'tab:gray'

    elif index == 8:
        colour = 'tab:orange'
        
    ax12.plot(average, colour, label = "{} cars/cell".format(i/100))
    ax12.set_title("Plot of Average Vehicle Speed to Max Speed Ratio for Various Densities [Over {} Simulations for Road Length of {} cells, Vmax = {}, Dawdling Probability = {}%]. ".format(max_iters, road_len, vmax, dawdeling ), fontsize=12)
    ax12.set_xlabel("Timestep [Arbitrary Units]",fontsize=20)
    ax12.set_ylabel("Velocity/ Vmax [c/t]", fontsize=20)
    ax12.legend(loc= 0, fontsize = 10)

# %% [markdown]
# Looking closer around the crital density value:

# %%
fig12 = plt.figure(figsize=(30,10))
ax12 = fig12.add_subplot(111)
index = 0
max_iters=100
timesteps = 500
road_len = 200
vmax = 5
dawdling_prob = 0.1
labels=[]
for i in [15, 15.5, 16, 16.5, 17]:
    average=np.zeros(timesteps)
    iters = 0
    while iters in range(max_iters):
        functioncall =Traffic(road_len, 0, vmax, 0, i/100, 0.0, 0.0, dawdling_prob, 0.0, 0.0, 1, timesteps, 1, 1, 1)[:,3]
        average += functioncall
        iters+=1
    average /= max_iters
    index+=1
    if index == 1:
        colour = "r"
    elif index == 2:
        colour = "b"

    elif index == 3:
        colour = "g"

    elif index == 4:
        colour = "c"

    elif index == 5:
        colour = "m"
        
    elif index == 6:
        colour = "y"
        
    elif index == 7:
        colour = 'tab:gray'

    elif index == 8:
        colour = 'tab:orange'
        
    ax12.plot(average, colour, label = "{} cars/cell".format(i/100))
    ax12.set_title("Plot of Average Vehicle Speed to Max Speed Ratio for Various Densities [Over {} Simulations for Road Length of {} cells, Vmax = {}, Dawdling Probability = {}%]. ".format(max_iters, road_len, vmax, dawdling_prob ), fontsize=20)
    ax12.set_xlabel("Timestep [Arbitrary Units]", fontsize=25)
    ax12.set_ylabel("Velocity/ Vmax [c/t]", fontsize=25)
    ax12.legend(loc= 0, fontsize=15)

# %% [markdown]
# Looking at various dawdeling probabilites:

# %%
fig12 = plt.figure(figsize=(30,10))
ax12 = fig12.add_subplot(111)
index = 0
max_iters=100
timesteps = 200
road_len = 100
vmax = 5
density = 0.15
labels=[]
for i in range(0, 51, 7):
    average=np.zeros(timesteps)
    iters = 0
    while iters in range(max_iters):
        functioncall =Traffic(100, 0, 5, 0, density, 0.0, 0.0, i/100, 0.0, 0.0, 1, timesteps, 1, 1, 1)[:,3]
        average += functioncall
        iters+=1
    average /= max_iters
    index+=1
    if index == 1:
        colour = "r"
    elif index == 2:
        colour = "b"

    elif index == 3:
        colour = "g"

    elif index == 4:
        colour = "c"

    elif index == 5:
        colour = "m"
        
    elif index == 6:
        colour = "y"
        
    elif index == 7:
        colour = 'tab:gray'

    elif index == 8:
        colour = 'tab:orange'

    ax12.plot(average, colour, label = "{} %".format(i))
    ax12.set_title("Plot of Average Vehicle Speed to Max Speed Ratio for Various Dawdeling Probabilites [Over {} Simulations for Road Length of {} cells, Vmax = {}, Density {} cars/cell]. ".format(max_iters, road_len, vmax, density ), fontsize=20)
    ax12.set_xlabel("Timestep [Arbitrary Units]", fontsize=25)
    ax12.set_ylabel("Velocity/ Vmax [c/t]", fontsize=25)
    ax12.legend(loc = 2,  fontsize=15)

# %% [markdown]
# Looking at the ratio of  max speed to the length of the road:

# %%
fig12 = plt.figure(figsize=(30,10))
ax12 = fig12.add_subplot(111)
index = 0
max_iters=100
timesteps = 50
road_len = 100
vmax = 5
dawdling_prob = 0.1
density = 0.15
labels=[]
for i in range(5, 14, 1):
    average=np.zeros(timesteps)
    iters = 0
    while iters in range(max_iters):
        functioncall =Traffic(road_len, 0, i, 0, density, 0.0, 0.0, dawdling_prob, 0.0, 0.0, 1, timesteps, 1, 1, 1)[:,3]
        average += functioncall
        iters+=1
    average /= max_iters
    index+=1
    if index == 1:
        colour = "r"
    elif index == 2:
        colour = "b"

    elif index == 3:
        colour = "g"

    elif index == 4:
        colour = "c"

    elif index == 5:
        colour = "m"
        
    elif index == 6:
        colour = "y"
        
    elif index == 7:
        colour = 'tab:gray'

    elif index == 8:
        colour = 'tab:orange'

    ax12.plot(average, colour, label = "{} c/t".format(i))
    ax12.set_title("Plot of Average Vehicle Speed to Max Speed Ratio for Various Max Speeds [Over {} Simulations for Road Length of {} cells, Vmax = {}, Dawdling Probability = {}% and Density {} cars/cell]. ".format(max_iters, road_len, vmax, dawdling_prob, density ), fontsize=15)
    ax12.set_xlabel("Timestep [Arbitrary Units]", fontsize=25)
    ax12.set_ylabel("Velocity/ Vmax [c/t]", fontsize=25)
    ax12.legend(loc= 2, fontsize=15)

# %% [markdown]
# This next cell plots the average speed of vehicles in each lane:

# %% [markdown]
# ### 8/3 cont ###
#
# Due to the stochastic nature, to gain a true representation of each system, we needed to average a full iteration multiple times. The number of full iterations that produced the most repeatable results was 100, however naturally this took its toll on my computer's memory and each result would take up to 5 minutes to process. This was mostly likelt due to multiple nested functions that look at every element in the array.
#
# ### 13/8 ###
#
# Now calling the 3 lane systems

# %% [markdown]
# Average number of motorbikes in each lane

# %%
fig12 = plt.figure(figsize=(10,10))
ax12 = fig12.add_subplot(111)
index = 0
max_iters=100
timesteps = 100
tol = 1e-6

labels=[]
i= "Left" 
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    #functioncall =triple_lane_road_periodic_accident(100, 4, 8, 12, 10/100, 0.3, 0.3, 10/100, 1, 100)[0::3,7]
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[0::3,7]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] /div[i]
    else:
        average[i] = "nan"
colour = "r"
ax12.plot(average[2:], colour)
 
i= "Middle" 
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[1::3,7]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
    
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] / div[i]
    else:
        average[i] = "nan"
colour = "b"
ax12.plot(average[2:], colour)

i= "Right"  
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[2::3,7]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] / div[i]
    else:
        average[i] = "nan"

colour = "g"

ax12.plot(average[2:], colour)
ax12.set_title("Plot of Number of Motorbikes in Each Lane,[Over {} Simulations for Road Length of {} cells. ".format(max_iters, 100))
ax12.set_xlabel("Timestep [Arbitrary Units]", fontsize=20)
ax12.set_ylabel(" Number [Motorbikes]", fontsize=20)
ax12.legend(labels)

# %% [markdown]
# Average number of cars in each lane

# %%
fig12 = plt.figure(figsize=(10,10))
ax12 = fig12.add_subplot(111)
index = 0
max_iters=100
timesteps = 100
tol = 1e-6

labels=[]
i= "Left" 
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[0::3,4]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] /div[i]
    else:
        average[i] = "nan"
colour = "r"
ax12.plot(average[2:], colour)
 
i= "Middle" 
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[1::3,4]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
    
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] / div[i]
    else:
        average[i] = "nan"
colour = "b"
ax12.plot(average[2:], colour)

i= "Right"  
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[2::3,4]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] / div[i]
    else:
        average[i] = "nan"

colour = "g"

ax12.plot(average[2:], colour)
ax12.set_title("Plot of Number of Cars in Each Lane,[Over {} Simulations for Road Length of {} cells. ".format(max_iters, 100))
ax12.set_xlabel("Timestep [Arbitrary Units]", fontsize=20)
ax12.set_ylabel(" Number [Cars]", fontsize=20)
ax12.legend(labels)

# %% [markdown]
# Average number of lorries in each lane

# %%
fig12 = plt.figure(figsize=(10,10))
ax12 = fig12.add_subplot(111)
index = 0
max_iters=100
timesteps = 100
tol = 1e-6

labels=[]
i= "Left" 
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[0::3,1]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] /div[i]
    else:
        average[i] = "nan"
colour = "r"
ax12.plot(average[2:], colour)
 
i= "Middle" 
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[1::3,1]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
    
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] / div[i]
    else:
        average[i] = "nan"
colour = "b"
ax12.plot(average[2:], colour)

i= "Right"  
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[2::3,1]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] / div[i]
    else:
        average[i] = "nan"

colour = "g"

ax12.plot(average[2:], colour)
ax12.set_title("Plot of Number of Motorbikes in Each Lane,[Over {} Simulations for Road Length of {} cells. ".format(max_iters, 100))
ax12.set_xlabel("Timestep [Arbitrary Units]", fontsize=20)
ax12.set_ylabel(" Number [Lorries]", fontsize=20)
ax12.legend(labels)

# %% [markdown]
# Average speed of each lane:

# %%
fig12 = plt.figure(figsize=(20,10))
ax12 = fig12.add_subplot(111)
index = 0
max_iters=100
timesteps = 100
tol = 1e-6

labels=[]
i= "Left" 
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[0::3,10]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] /div[i]
    else:
        average[i] = "nan"
colour = "r"
ax12.plot(average[2:], colour)
 
i= "Middle" 
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[1::3,10]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
    
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] / div[i]
    else:
        average[i] = "nan"
colour = "b"
ax12.plot(average[2:], colour)

i= "Right"  
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[2::3,10]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] / div[i]
    else:
        average[i] = "nan"

colour = "g"

ax12.plot(average[2:], colour)
ax12.set_title("Plot of Average Speed to Max Speed Ratio in Each Lane,[Over {} Simulations for Road Length of {} cells. ".format(max_iters, 100))
ax12.set_xlabel("Timestep [Arbitrary Units]", fontsize=20)
ax12.set_ylabel(" V/Vmax [c/t]", fontsize=20)
ax12.legend(labels)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-864b6786a032> in <module>
#      54 iters = 0
#      55 while iters in range(timesteps):
# ---> 56     functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[2::3,10]
#      57     average += functioncall
#      58     for i in range(timesteps):
#
# <ipython-input-2-6d8dca8621c4> in Traffic(n, vmax_lorries, vmax_cars, vmax_bikes, density, percent_lorries, percent_bikes, prob_car_daw, lane_change_prob, blockage, evasive, max_iterations, road_type, dis_type, output)
#     276
#     277                                                 middlelane = np.delete(middlelane, i)
# --> 278                                                 middleane = np.insert(middlelane, i, 0)
#     279
#     280                                                 if rightlane[i]<vmax:
#
# ...

# %% [markdown]
# Average speed of each lane with a road closure introduced

# %%
fig12 = plt.figure(figsize=(20,5))
ax12 = fig12.add_subplot(111)
index = 0
max_iters=100
timesteps = 100
tol = 1e-6

labels=[]
i= "Left" 
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[0::3,11]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] /div[i]
    else:
        average[i] = "nan"
colour = "r"
ax12.plot(average[2:], colour)
 
i= "Middle" 
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[1::3,11]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
    
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] / div[i]
    else:
        average[i] = "nan"
colour = "b"
ax12.plot(average[2:], colour)

i= "Right"  
labels.append(i)
average=np.zeros(timesteps)
div= np.zeros(timesteps)
iters = 0
while iters in range(timesteps):
    functioncall =Traffic(100, 4, 8, 12, 10/100, 0.3, 0.3, 2/100, 1, 0.0, 1, timesteps, "Multi", 1, 1)[2::3,11]
    average += functioncall
    for i in range(timesteps):
        if functioncall[i]>tol:
            div[i]+=1
    iters+=1
for i in range(2, timesteps):
    if div[i]>0:
        average[i]= average[i] / div[i]
    else:
        average[i] = "nan"

colour = "g"

ax12.plot(average[2:], colour)
ax12.set_title("Plot of Average Speed to Max Speed Ratio in Each Lane,[Over {} Simulations for Road Length of {} cells.".format(max_iters, 100))
ax12.set_xlabel("Timestep [Arbitrary Units]", fontsize=20)
ax12.set_ylabel(" V/Vmax [c/t]", fontsize=20)
ax12.legend(labels)

# %% [markdown]
# ### 21/3 ###
#
# Then I moved back to the single lane system to be able to see if I could see if there was a wave like nature to the jams

# %%
def single_lane_road_periodic(n, div, vmax, density, prob_car_daw, max_iterations):
    ''' Function to generate a road and while cars are generated and move according to a set of rules.
        Inputs:
        n = length of the road
        div = rate of new cars joining the road
        vmax = max speed of the cars
        density = density of cars on the road
        prob_car_daw = probability of the cars dawdeling 
        max_iterations = number of timesteps
    ''' 
    
    #Create empty road and matrix to store iterations
    road = np.zeros(n)                          
    matrix = np.zeros((max_iterations, n))
    data= np.zeros((max_iterations, 4))
    acc = np.zeros((max_iterations, n))
    clus =  np.zeros((max_iterations, n))
    iterations = 1
    tol = 1e-4
    
    ### Car Generation ###
    for i in range(round(n*density)):
        ranspace = np.random.randint(0, n)
        while road[ranspace]!=0:
            ranspace = np.random.randint(0, n)
        road[ranspace]=np.random.randint(2, vmax) 

        
    while iterations in range(max_iterations):
        
        #create loop like extention to the end of the road
        road = np.concatenate((road, road))
        
        ### Rule 1 ###
        
        # If the velocity v of the car is lower than vmax , and the distance to the next car
        # ahead is larger than v + 1, the speed is increased by one.
        for i in range(2*n-6,  -1, -1):
            if road[i]>1:                               
                if sum(road[i+1:i+int(road[i])])==0:
                    if road[i]<vmax:
                        road[i]+=1
            
            
                ### Rule 2###
                
                # If a driver at site i sees the next vehicle at site i+j, with j < v, 
                # they reduce speed to j −1.  
                else:
                    count = 0
                    #If there is a car directly in front slow to stationary.
                    if road[i+1]!=0:            
                        road[i]=1
                    else:
                        while road[i + count+ 1]<1:
                             #Count is the distance between two cars.
                            count+=1 
                        road[i]=count    
                            
       
        ### Rule 4 ###
        
        # Each vehicle is advanced by v sites.
        
            #Special case where car is stationary.
            elif road[i]==1:                              
                #If no cars in front, start moving at v=1.
                if road[i+1]!=1:                
                    road[i]=2
                else:
                    road[i]=1
        
        
        # As the vechicles move forward we have to iterate in reverse as cars move forward.
        for i in range(2*n-6, -1, -1):    

            #cars move forward 
            if road[i]>0:                       
                road= np.insert(road, i+int(road[i]), int(road[i]))       
                road = np.delete(road, i)
                #road[i+int(road[i])-1] = int(road[i])
                #road[i]=0

        
        #reduce the road back to the original shape
        road = np.concatenate((road[n:n+int(n/2)], road[int(n/2):n]))
        
        ###Rule 3 ###
                
        # The velocity of each moving vehicle is decreased by one with probability p.
        for i in range(n):
            if np.random.randint(1, 100)<prob_car_daw*100:       
                if road[i]>1:                                     
                    road[i]-=1
                        
        
        #Visualisation
        for i in range(np.size(road)):
            if road[i]==0:
                matrix[iterations,i]= 0
            else:
                matrix[iterations,i]= 1
                
                
        ### Alternate visualiation tools ###
        
        #street = []
        #for i in range(np.size(road)):
        #    if road[i]==0:
        #        street.append(' ')
        #    else:
        #        street.append(road[i]-1)
        #print(iterations , street, np.count_nonzero(road))
    
       
        ### Data collection ###
        data[iterations, 0]= iterations
        #car density
        data[iterations, 1]= np.count_nonzero(road)/n
        #average speed- accouting for the fact the values are one greater than the speed
        data[iterations, 2]= round(sum(road)/np.count_nonzero(road) -1, 2)
        data[iterations, 3]= round((np.count_nonzero(road)/n)*sum(road)/np.count_nonzero(road) -1, 2) 
        
        #average speed over all iterations
        av = round(sum(data[:,2])/max_iterations, 2)
        
        for i in range(np.size(road)- vmax):
            #if road[i]<tol:
            #    acc[iterations, i] = -5
            #else:     
            #    acc[iterations, i] = (road[i]-road[i-1])    
            
            countdiff = 1
            while road[i +countdiff]<tol and countdiff<vmax:
                 #Count is the distance between two cars.
                countdiff+=1   
                
            #if road[i]>tol:
            #    acc[iterations, i] = abs(road[i]-road[i+countdiff])
            #else:
            #    acc[iterations, i] = -1
            
            #acc[iterations, i] = countdiff
            
            #if abs(countdiff-1)<tol and sum(road[i:i+4])<4:
                #acc[iterations, i]=1
                
            if road[i]>tol and abs(road[i]-road[i+countdiff]-1)<tol:
                acc[iterations, i] = 1
                
            if abs(countdiff-1)<tol and sum(road[i:i+4])<4:
                clus[iterations, i]=1
    
        ###next time step ###
        iterations +=1
 
    return acc, clus, road

# %%
fig12 = plt.figure(figsize=(20,5))

index = 1
timesteps = 300
labels=[]
acc, clus, road = single_lane_road_periodic(1000, 2, 6, 16/100, 6/100, timesteps)

ax12 = fig12.add_subplot(1,1, 1)
#ax12.plot(acc[200])
ax12.plot(clus[200])
ax12.set_title("Areas of Slow-Moving Vehicles at the 200th Timestep [Over {} Simulations for Road Length of {} cells.]".format(max_iters, 1000), fontsize=20)
ax12.set_ylabel("[Arbitrary Units]", fontsize=20)
ax12.set_xlabel(" Length along the road [Cells]", fontsize=20)

# %% [markdown]
# ### 21/3 cont ###
#
# In order to try and determine the wavelenghts of these traffic waves (if there are any) I looked at implementing several differnt approaches (all have been left in the code, simply commented out:
# Initilaly I looked at using a finite difference to determine the acceleration of the wave from the velocities of the cars like so:
#
#     for i in range(np.size(road)- 1):
#         acc[iterations, i] = (road[i+1]-road[i1])
#
# which taking into account that we cannot discretise to a value of dv lower than one. However as each cell is then surrounded by a zero value empty space this produced a figure of very little relevence as it was essentilly a plot of the vehciles velocities, and any areas of build up, where two adjacent stationary cars, which had an element value of 1 (thus a velocity of zero) would have a difference of zero, which could not be decerned from the empty spaces.
#
# In order to combat that I looked to give the empty spaces a negative value:
#
# for i in range(np.size(road)- vmax):
#             if road[i]<tol:
#                 acc[iterations, i] = -1
#             else:
#                 acc[iterations, i] = (road[i]-road[i-1])
#
# However this made the plot unreadable, and not partically useful.
#
# Thus i tried to look at the difference in velocities between each car and the one that was in front of it:
#         for i in range(np.size(road)- vmax):
#
#             countdiff = 1
#             while road[i +countdiff]<tol and countdiff<vmax:
#                  #Count is the distance between two cars.
#                 countdiff+=1
#             if road[i]>tol:
#                 acc[iterations, i] = abs(road[i]-road[i+countdiff])
#             else:
#                 acc[iterations, i] = -1
#
# Again setting the spaces not occupied by cars to -1, which is the only way to decern them from the zero values were are looking for to indicate 2 stationary adjacent vehicles.
#
# So to fix this only the zero values were are looking for are plotted and the rest it set to zero using:
#
#             if road[i]>tol and abs(road[i]-road[i+countdiff]-1)<tol:
#                 acc[iterations, i] = 1
#
# This gives us sharp lines where two adjacant cars are both stationary, however this still doesn't tell us much about the wave nature, whether these veheicles are are the start, back or in the middle of a traffic jam.
#
# Thus I am going to try and look at larger groups of cells to observe their motion. This proved much more useful. Looking at these clusters, if the sum of the values of 4 cells where at least two filled by adjacent cars, is less than 4, we can assume that the cars in that group are slow moving, and thus stuck in traffic. When plotting this it proved far more useful:
#
#     for i in range(np.size(road)- vmax):
#             countdiff = 1
#             while road[i +countdiff]<tol and countdiff<vmax:
#                  #Count is the distance between two cars.
#                 countdiff+=1
#             if abs(countdiff-1)<tol and sum(road[i:i+4])<4:
#                 clus[iterations, i]=1
#
# Here we see groups of slow moving and staionary cars, which indicate areas of traffic that have formed. This was conducted over larger road, 1000 cells, to see if these traffic jam waves repeat.
#
# We observe clusters however it is very diffiult to attempt to measure a wavelength, or any sort of pattern. And this may be due to the nature of the jams, they do not act as waves that osccilate, but are areas of turbulence and thus are very diffuclt to measure.
#
# Thus it may be more useful to see if anything can be made of the speed that the jam moves back through the road. We can reduce the road back down to a smaller size in order to better be able to measure the recession of the jam. However what can be seen is that it moves back in an a non uniform manner and thus it is very difficult to measure a velocity. This makes sense, as it can be seen clearly from the shape of the traffic jam, which seems to meander, changing shape and size non-uniformly. One would expect this is from the stochastic nature of the model.

# %%
fig13 = plt.figure(figsize=(20,20))

index = 1
timesteps = 300
labels=[]
acc, clus, road = single_lane_road_periodic(150, 2, 6, 16/100, 6/100, timesteps)

for i in range(200, 261):
    if i%20==0:
        
        ax13 = fig13.add_subplot(4,1, index)
        ax13.plot(acc[i])
        ax13.plot(clus[i])
        index+=1
